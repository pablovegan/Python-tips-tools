# %% [markdown]
# References http://python-history.blogspot.com/2013/11/story-of-none-true-false.html

# %% [markdown]
# Builtins

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
copyright
# Out:
# Copyright (c) 2001-2023 Python Software Foundation.
# All Rights Reserved.
#
# Copyright (c) 2000 BeOpen.com.
# All Rights Reserved.
#
# Copyright (c) 1995-2001 Corporation for National Research Initiatives.
# All Rights Reserved.
#
# Copyright (c) 1991-1995 Stichting Mathematisch Centrum, Amsterdam.
# All Rights Reserved.

# %% [markdown]
# Python builtins can be overwritten

# %%
copyright = 3
int = 4
abs = 3

# %% [markdown]
# Literals cannot ve overwritten because the parser detects an invalid syntax.

# %%
# Doesn't work
None = 2
2 = 3
"a" = 3
# Out:
#   Cell In[5], line 1
#     None = 2
#     ^
# SyntaxError: cannot assign to None

# %% [markdown]
# One cannot overrride keywords (reserved words)

# %%
if = 2
# Out:
#   Cell In[1], line 1
#     if = 2
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# The dis function from the dis module gives you back the tokens that the abstract syntax tree that python uses to represent it.

# %%
two = 2

def add_two_plus_two():
    return two + two

# %%
import dis

dis.dis(add_two_plus_two)
# Out:
#   3           0 RESUME                   0
#
#   4           2 LOAD_GLOBAL              0 (two)
#              14 LOAD_GLOBAL              0 (two)
#              26 BINARY_OP                0 (+)
#              30 RETURN_VALUE
